# %%
import pandas as pd
import random

# Categorias de peças automotivas
categorias = ['Motor', 'Suspensão', 'Freios', 'Elétrica']

# Gerar lista de produtos
produtos = []
for i in range(1, 21):
    categoria = random.choice(categorias)
    produtos.append({
        'id_produto': f'P{i:03}',
        'nome_produto': f'Produto {i}',
        'categoria': categoria
    })

df_produtos = pd.DataFrame(produtos)
df_produtos.to_csv('produtos.csv', index=False)
print(df_produtos.head())
# Out:
#   id_produto nome_produto categoria
# 0       P001    Produto 1  Elétrica
# 1       P002    Produto 2     Motor
# 2       P003    Produto 3    Freios
# 3       P004    Produto 4    Freios
# 4       P005    Produto 5     Motor
